# %% [markdown]
# # Biological Models
#
#
# Search for the optimal biological model.
#
# ----
# ```
# author:     Zach Wolpe
# email:      zachcolinwolpe@gmail.com
# date:       21 January 2022
# ```
# ----

# %%
import sys
sys.path.append('../process data')
from dependencies import *

# %%
# load -------------------------------------*
loc = '/Users/zachwolpe/Documents/Production/Dynocog/Python Implementation/final instance/model-free analysis/final_dataframes'
wcst_data   = pd.read_pickle(loc + '/wcst_raw_data.pkl')
wcst        = pd.read_pickle(loc + '/wcst.pkl')
covariates  = pd.read_pickle(loc + '/covariates.pkl')
wcst
# Out:
#        participant  reward  status action   rule  n_t
# 0         816404.0       1       1      1  shape    0
# 1         816404.0       1       1      1  shape    1
# 2         816404.0       1       1      1  shape    2
# 3         816404.0       1       1      1  shape    3
# 4         816404.0       1       1      1  shape    4
# ...            ...     ...     ...    ...    ...  ...
# 27395     684712.0       1       1      3  color   95
# 27396     684712.0       1       1      3  color   96
# 27397     684712.0       1       1      3  color   97
# 27398     684712.0       1       1      3  color   98
# 27399     684712.0       1       1      3  color   99
#
# [27400 rows x 6 columns]

# %% [markdown]
# # Null Bio-Model
#
# Single learning rate.
#
# ## Transform the data

# %%
wcst.action   = wcst.action.astype(int)
wcst.reward   = wcst.reward.astype(int)
action_matrix = wcst[['participant' ,'n_t', 'action']].pivot(index='participant', columns='n_t')
reward_matrix = wcst[['participant' ,'n_t', 'reward']].pivot(index='participant', columns='n_t')
data_object = {
    'n_s':    reward_matrix.shape[0],
    'n_t':    reward_matrix.shape[1],
    'action': action_matrix,
    'reward': reward_matrix+1
}

# %%
type(action_matrix.iloc[0,0])
# Out:
# numpy.int64

# %%
wcst.n_t
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 27395    95
# 27396    96
# 27397    97
# 27398    98
# 27399    99
# Name: n_t, Length: 27400, dtype: int64

# %%
model = """

data {
  int<lower=1> n_s;
  int<lower=1> n_t;
  int action[n_s, n_t];     
  int reward[n_s, n_t]; 
}

transformed data {
  vector[3] initQs;  // initial values for V
  initQs = rep_vector(0.3333, 3);
}

parameters {
  real<lower=0,upper=1> a_mu;
  real<lower=0,upper=10> b_mu;

  real<lower=0> a_sd;
  real<lower=0> b_sd;

  real<lower=0,upper=1> a[n_s];
  real<lower=0,upper=10> b[n_s];  
}

model {
  // individual variance priors! 
  a_sd  ~ cauchy(0,1);
  b_sd ~ cauchy(0,3);
  
  // give the prior here: how individual-level parameters are connected to the group-level parameters
  a ~ normal(a_mu, a_sd);
  b ~ normal(b_mu, b_sd);
  
  
  for (s in 1:n_s) {
    vector[3] Qs; 
    real pe;    
    Qs = initQs;

    for (t in 1:n_t) {        
      action[s,t] ~ categorical_logit( b[s] * Qs);
      pe = reward[s,t] - 1 - Qs[action[s,t]];      
      Qs[action[s,t]] = Qs[action[s,t]] + a[s] * pe; 
    }
  }    
}


// include log-likelihood calculation
generated quantities {
  real                    log_lik[n_s];

  { // local section, this saves time and space
    for (s in 1:n_s) {
      vector[3] Qs; 
      real pe;    

      log_lik[s] = 0;
      Qs = initQs;

      for (t in 1:n_t) {    
        log_lik[s] = log_lik[s] + categorical_logit_lpmf(action[s,t] | b[s] * Qs);    
              
        pe = reward[s,t] - 1 - Qs[action[s,t]];      
        Qs[action[s,t]] = Qs[action[s,t]] + a[s] * pe; 
      }
    }    
  }
}

"""

fit   = pystan.stan(model_code=model, warmup=1000, data=data_object, iter=2000, chains=2)
# Out:
# WARNING:pystan:DeprecationWarning: pystan.stan was deprecated in version 2.17 and will be removed in version 3.0. Compile and use a Stan program in separate steps.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_d500a01348f558f4f52414388e38da00 NOW.
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:771:
# In file included from /Users/zachwolpe/.local/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Users/zachwolpe/.local/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/zachwolpe/.local/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1944:
# /Users/zachwolpe/.local/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:52:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor_corr.hpp:5:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor.hpp:6:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_lower_triangular.hpp:25:27: warning: 'ptr_fun<double, double>' is deprecated [-Wdeprecated-declarations]
#   return y.unaryExpr(std::ptr_fun(internal::notNan))
#                           ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/functional:1111:1: note: 'ptr_fun<double, double>' has been explicitly marked deprecated here
# _LIBCPP_DEPRECATED_IN_CXX11 inline _LIBCPP_INLINE_VISIBILITY
# ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/__config:1026:39: note: expanded from macro '_LIBCPP_DEPRECATED_IN_CXX11'
# #  define _LIBCPP_DEPRECATED_IN_CXX11 _LIBCPP_DEPRECATED
#                                       ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/__config:1015:48: note: expanded from macro '_LIBCPP_DEPRECATED'
# #    define _LIBCPP_DEPRECATED __attribute__ ((deprecated))
#                                                ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:24:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix.hpp:19:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2227:21: warning: misleading indentation; statement is not part of the previous 'if' [-Wmisleading-indentation]
#                     if (it2_ != it2_end_) {
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2224:17: note: previous statement is here
#                 if (it2_ != it2_end_)
#                 ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:781:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan_fit.hpp:841:12: warning: 'auto_ptr<stan::io::var_context>' is deprecated [-Wdeprecated-declarations]
#       std::auto_ptr<stan::io::var_context> init_context_ptr;
#            ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/memory:1181:28: note: 'auto_ptr<stan::io::var_context>' has been explicitly marked deprecated here
# class _LIBCPP_TEMPLATE_VIS _LIBCPP_DEPRECATED_IN_CXX11 auto_ptr
#                            ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/__config:1026:39: note: expanded from macro '_LIBCPP_DEPRECATED_IN_CXX11'
# #  define _LIBCPP_DEPRECATED_IN_CXX11 _LIBCPP_DEPRECATED
#                                       ^
# /Users/zachwolpe/miniforge3/bin/../include/c++/v1/__config:1015:48: note: expanded from macro '_LIBCPP_DEPRECATED'
# #    define _LIBCPP_DEPRECATED __attribute__ ((deprecated))
#                                                ^
# /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:9546:30: warning: comparison of integers of different signs: 'Py_ssize_t' (aka 'long') and 'std::vector<std::string>::size_type' (aka 'unsigned long') [-Wsign-compare]
#     __pyx_t_12 = ((__pyx_t_9 != __pyx_v_fitptr->param_names_oi().size()) != 0);
#                    ~~~~~~~~~ ^  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:473:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/products/GeneralMatrixVector.h:186:39: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#   const Index offset1 = (FirstAligned && alignmentStep==1)?3:1;
#                                       ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/GeneralProduct.h:239:131: note: in instantiation of member function 'Eigen::internal::general_matrix_vector_product<long, double, Eigen::internal::const_blas_data_mapper<double, long, 0>, 0, false, double, Eigen::internal::const_blas_data_mapper<double, long, 1>, false, 0>::run' requested here
#           <Index,LhsScalar,LhsMapper,ColMajor,LhsBlasTraits::NeedToConjugate,RhsScalar,RhsMapper,RhsBlasTraits::NeedToConjugate>::run(
#                                                                                                                                   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:377:31: note: in instantiation of function template specialization 'Eigen::internal::gemv_dense_selector<2, 0, true>::run<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>' requested here
#                            >::run(actual_lhs, actual_rhs, dst, alpha);
#                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:355:14: note: in instantiation of function template specialization 'Eigen::internal::generic_product_impl<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::DenseShape, Eigen::DenseShape, 7>::scaleAndAddTo<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>' requested here
#   { Derived::scaleAndAddTo(dst,lhs,rhs,alpha); }
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:351:5: note: in instantiation of function template specialization 'Eigen::internal::generic_product_impl_base<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::internal::generic_product_impl<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::DenseShape, Eigen::DenseShape, 7>>::scaleAndAddTo<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>' requested here
#   { scaleAndAddTo(dst, lhs, rhs, Scalar(-1)); }
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:178:37: note: in instantiation of function template specialization 'Eigen::internal::generic_product_impl_base<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::internal::generic_product_impl<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, Eigen::DenseShape, Eigen::DenseShape, 7>>::subTo<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>' requested here
#     generic_product_impl<Lhs, Rhs>::subTo(dst, src.lhs(), src.rhs());
#                                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: (skipping 2 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:321:38: note: in instantiation of function template specialization 'Eigen::NoAlias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::MatrixBase>::operator-=<Eigen::Product<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, 0>>' requested here
#       if (k>0 && rs>0) A21.noalias() -= A20 * A10.adjoint();
#                                      ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:473:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/products/GeneralMatrixVector.h:187:39: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#   const Index offset3 = (FirstAligned && alignmentStep==1)?1:3;
#                                       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>>, Eigen::internal::assign_op<double, double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>>, Eigen::internal::assign_op<double, double>, 0>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::assign_op<double, double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::assign_op<double, double>, Eigen::internal::Dense2Dense>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::assign_op<double, double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:3: note: (skipping 12 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(dst, src, internal::assign_op<typename Dst::Scalar,typename Src::Scalar>());
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:321:38: note: in instantiation of function template specialization 'Eigen::NoAlias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::MatrixBase>::operator-=<Eigen::Product<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, 0>>' requested here
#       if (k>0 && rs>0) A21.noalias() -= A20 * A10.adjoint();
#                                      ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::assign_op<double, double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::assign_op<double, double>, 0>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::internal::assign_op<double, double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::internal::assign_op<double, double>, Eigen::internal::Dense2Dense>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::internal::assign_op<double, double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:3: note: (skipping 10 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(dst, src, internal::assign_op<typename Dst::Scalar,typename Src::Scalar>());
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:321:38: note: in instantiation of function template specialization 'Eigen::NoAlias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::MatrixBase>::operator-=<Eigen::Product<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, 0>>' requested here
#       if (k>0 && rs>0) A21.noalias() -= A20 * A10.adjoint();
#                                      ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1, 0>>, const Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>>, Eigen::internal::add_assign_op<double, double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1, 0>>, const Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>>, Eigen::internal::add_assign_op<double, double>, 0>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1, 0>>, const Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::add_assign_op<double, double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1, 0>>, const Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::add_assign_op<double, double>, Eigen::internal::Dense2Dense>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1, 0>>, const Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::add_assign_op<double, double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/CwiseBinaryOp.h:177:3: note: (skipping 8 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(derived(), other.derived(), internal::add_assign_op<Scalar,typename OtherDerived::Scalar>());
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:321:38: note: in instantiation of function template specialization 'Eigen::NoAlias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::MatrixBase>::operator-=<Eigen::Product<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, 0>>' requested here
#       if (k>0 && rs>0) A21.noalias() -= A20 * A10.adjoint();
#                                      ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::assign_op<double, double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>>, Eigen::internal::assign_op<double, double>, 0>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::internal::assign_op<double, double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::internal::assign_op<double, double>, Eigen::internal::Dense2Dense>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::Map<Eigen::Matrix<double, -1, 1, 0>, 2>, Eigen::internal::assign_op<double, double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:3: note: (skipping 12 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(dst, src, internal::assign_op<typename Dst::Scalar,typename Src::Scalar>());
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:321:38: note: in instantiation of function template specialization 'Eigen::NoAlias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::MatrixBase>::operator-=<Eigen::Product<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, -1, false>, Eigen::Transpose<const Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, 1, -1, false>>, 0>>' requested here
#       if (k>0 && rs>0) A21.noalias() -= A20 * A10.adjoint();
#                                      ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>>, Eigen::internal::div_assign_op<double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>>, Eigen::internal::div_assign_op<double>, 0>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::div_assign_op<double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::div_assign_op<double>, Eigen::internal::Dense2Dense>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>, Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1, 0>>, Eigen::internal::div_assign_op<double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/SelfCwiseBinaryOp.h:45:13: note: (skipping 1 context in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   internal::call_assignment(this->derived(), PlainObject::Constant(rows(),cols(),other), internal::div_assign_op<Scalar,Scalar>());
#             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:322:21: note: in instantiation of member function 'Eigen::DenseBase<Eigen::Block<Eigen::Matrix<double, -1, -1, 0>, -1, 1, false>>::operator/=' requested here
#       if (rs>0) A21 /= x;
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:333:14: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::unblocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#       return unblocked(m);
#              ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:397:61: note: in instantiation of function template specialization 'Eigen::internal::llt_inplace<double, 1>::blocked<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   { return llt_inplace<typename MatrixType::Scalar, Lower>::blocked(m)==-1; }
#                                                             ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Cholesky/LLT.h:444:21: note: in instantiation of member function 'Eigen::internal::LLT_Traits<Eigen::Matrix<double, -1, -1, 0>, 1>::inplace_decomposition' requested here
#   bool ok = Traits::inplace_decomposition(m_matrix);
#                     ^
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:84:7: note: in instantiation of function template specialization 'Eigen::LLT<Eigen::Matrix<double, -1, -1, 0>, 1>::compute<Eigen::Matrix<double, -1, -1, 0>>' requested here
#   llt.compute(m);
#       ^
# In file included from /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/pystan_udifyj1i/stanfit4anon_model_d500a01348f558f4f52414388e38da00_644543329292557634.cpp:780:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/zachwolpe/miniforge3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
# ...
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# Process SpawnPoolWorker-21:
# Process SpawnPoolWorker-22:
# Process SpawnPoolWorker-16:
# Process SpawnPoolWorker-18:
# Process SpawnPoolWorker-13:
# Process SpawnPoolWorker-20:
# Process SpawnPoolWorker-19:
# Process SpawnPoolWorker-17:
# Process SpawnPoolWorker-15:
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/queues.py", line 366, in get
#     res = self._reader.recv_bytes()
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/zachwolpe/miniforge3/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniforge3/lib/python3.9/site-packages/pystan/model.py in _map_parallel(function, args, n_jobs)
#      84             pool = multiprocessing.Pool(processes=n_jobs)
# ---> 85             map_result = pool.map(function, args)
#      86         finally:
#
# ~/miniforge3/lib/python3.9/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#
# ~/miniforge3/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#
# ~/miniforge3/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#
# ~/miniforge3/lib/python3.9/threading.py in wait(self, timeout)
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#
# ~/miniforge3/lib/python3.9/threading.py in wait(self, timeout)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/kd/p1z7_f_974d7tkw1zmvskn_m0000gn/T/ipykernel_21250/3718168997.py in <module>
#      72 """
#      73
# ---> 74 fit   = pystan.stan(model_code=model, warmup=1000, data=data_object, iter=2000, chains=2)
#
# ~/miniforge3/lib/python3.9/site-packages/pystan/api.py in stan(file, model_name, model_code, fit, data, pars, chains, iter, warmup, thin, init, seed, algorithm, control, sample_file, diagnostic_file, verbose, boost_lib, eigen_lib, include_paths, n_jobs, allow_undefined, **kwargs)
#     441             raise ValueError("Parameter `{}` is not recognized.".format(arg))
#     442
# --> 443     fit = m.sampling(data, pars=pars, chains=chains, iter=iter,
#     444                      warmup=warmup, thin=thin, seed=seed, init=init,
#     445                      sample_file=sample_file, diagnostic_file=diagnostic_file,
#
# ~/miniforge3/lib/python3.9/site-packages/pystan/model.py in sampling(self, data, pars, chains, iter, warmup, thin, seed, init, sample_file, diagnostic_file, verbose, algorithm, control, n_jobs, **kwargs)
#     811         call_sampler_args = izip(itertools.repeat(data), args_list, itertools.repeat(pars))
#     812         call_sampler_star = self.module._call_sampler_star
# --> 813         ret_and_samples = _map_parallel(call_sampler_star, call_sampler_args, n_jobs)
#     814         samples = [smpl for _, smpl in ret_and_samples]
#     815
#
# ~/miniforge3/lib/python3.9/site-packages/pystan/model.py in _map_parallel(function, args, n_jobs)
#      86         finally:
#      87             pool.close()
# ---> 88             pool.join()
#      89     else:
#      90         map_result = list(map(function, args))
#
# ~/miniforge3/lib/python3.9/multiprocessing/pool.py in join(self)
#     660         elif self._state not in (CLOSE, TERMINATE):
#     661             raise ValueError("In unknown state")
# --> 662         self._worker_handler.join()
#     663         self._task_handler.join()
#     664         self._result_handler.join()
#
# ~/miniforge3/lib/python3.9/threading.py in join(self, timeout)
#    1051
#    1052         if timeout is None:
# -> 1053             self._wait_for_tstate_lock()
#    1054         else:
#    1055             # the behavior of a negative timeout isn't documented, but
#
# ~/miniforge3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1067         if lock is None:  # already determined that the C code is done
#    1068             assert self._is_stopped
# -> 1069         elif lock.acquire(block, timeout):
#    1070             lock.release()
#    1071             self._stop()
#
# KeyboardInterrupt:

# %%
print(fit)

# %%
loo, loos, ks = psisloo(fit['log_lik'])
print('PSIS-LOO value: {:.2f}'.format(loo))

# %%
import arviz as az
az.plot_trace(fit);

# %%
import plotly.express as px
print('Alpha: ', np.mean(fit['a_mu']))
px.histogram(x=fit['a_mu'], template='none', opacity=0.8,
                  #  log_y=True, # represent bars with log scale
                   color_discrete_sequence=['lightblue'])

# print('beta: ', np.mean(fit['b_mu']))
# px.histogram(x=fit['b_mu'], template='none')
